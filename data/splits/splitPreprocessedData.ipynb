# %%
import pandas as pd
import numpy as np

# %%
print("="*30+" Before split "+"*"*30+"")
print(f"Indian liver patient dattaset: {indian_liver_patient.shape}")
print(f"Cirhosis dattaset: {cirrhosis.shape}\n")

train_liver = indian_liver_patient.sample(frac=0.8, random_state=42)
test_liver = indian_liver_patient.drop(train_liver.index)
train_cirrhosis = cirrhosis.sample(frac=0.8, random_state=42)
test_cirrhosis = cirrhosis.drop(train_cirrhosis.index)

print("="*30+" After split "+"*"*30+"")
print(f"Indian liver patient train dattaset: {train_liver.shape}")
print(f"Indian liver patient test dattaset: {test_liver.shape}")
print(f"Cirhosis train dattaset: {train_cirrhosis.shape}")
print(f"Cirhosis test dattaset: {test_cirrhosis.shape}")
# Out:
# ============================== Before split ******************************
# Indian liver patient dattaset: (30691, 11)
# Cirhosis dattaset: (5271, 19)
#
# ============================== After split ******************************
# Indian liver patient train dattaset: (24553, 11)
# Indian liver patient test dattaset: (6138, 11)
# Cirhosis train dattaset: (4217, 19)
# Cirhosis test dattaset: (1054, 19)

# %%
train_liver.to_csv('/content/split/train_liver.csv', index=False)
test_liver.to_csv('/content/split/test_liver.csv', index=False)
train_cirrhosis.to_csv('/content/split/train_cirrhosis.csv', index=False)
test_cirrhosis.to_csv('/content/split/test_cirhossis.csv', index=False)
